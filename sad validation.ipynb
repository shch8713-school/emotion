# %%
from itertools import count
import numpy as np
import argparse
import cv2
from PIL import ImageGrab
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import csv
import time
import socket
from imutils.video import VideoStream
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import pandas
from sklearn import model_selection
# from sklearn.linear_model import LogisticRegression
import joblib
import pandas as pd

model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

model.load_weights('C:/Users/User/Desktop/ERS/model.h5')

# %%
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
#     objects = ('angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
import cv2
import os
import numpy as np
import torch

# input folder
folder='C:/Users/User/Desktop/test/sad'

images = []
# for filename in os.listdir(folder):
#     img = cv2.imread(os.path.join(folder,filename))

#     if img is not None:
#         images.append(img)
        
# print(images)
def facecrop(image):  
    facedata = 'C:/Users/User/Desktop/ERS/haar cascade files/haarcascade_frontalface_default.xml'
    cascade = cv2.CascadeClassifier(facedata)
    img_num = 0
    
    for filename in os.listdir(folder):
        img_num += 1
        img = cv2.imread(os.path.join(folder,filename))
        
        if img is not None:
            images.append(img)

        try:

            minisize = (img.shape[1],img.shape[0])
            miniframe = cv2.resize(img, minisize)

            faces = cascade.detectMultiScale(miniframe)

            for f in faces:
                x, y, w, h = [ v for v in f ]
                cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

                sub_face = img[y:y+h, x:x+w]

                # images output folder
                cv2.imwrite('C:/Users/User/Desktop/test/sad_valid/capture{0}.jpg'.format(img_num), sub_face)
                #print ("Writing: " + image)

        except Exception as e:
            print (e)

   

if __name__ == '__main__':
    # first image to start looping 
    facecrop('C:/Users/User/Desktop/test/sad/im0.png')
#Testing a file.


# Redo comment below
# ------------------------------------------------------------------------------------------

# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import spicy as sc
from scipy import misc


folder_valid = 'C:/Users/User/Desktop/test/sad_valid'
# 'C:/Users/User/Desktop/test/angry_valid/capture  {0}.jpg'
all_vald_img = []
photo_count = 0
angry = 0
disgust = 0
fear = 0
happy = 0
sad = 0
surprise = 0
neutral = 0
    
for filename_valid in os.listdir(folder_valid):
    photo_count += 1
    img_valid = cv2.imread(os.path.join(folder_valid,filename_valid))
    if img_valid is not None:
        all_vald_img.append(img_valid)

# print(all_vald_img)

# print(len(all_vald_img))
#     if photo_count == len(all_vald_img):
#         pass
    try:
        file  = 'C:/Users/User/Desktop/test/sad_valid/capture{0}.jpg'.format(photo_count)
        print(photo_count)
        true_image = image.load_img(file)
        img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))


        #  --------------------------------------------------------------------------------
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis = 0)

        x /= 255

        custom = model.predict(x)
        emotion_analysis(custom[0])
        emo_reff = {'angry': custom[0][0], 'disgust': custom[0][1], 'fear': custom[0][2], 'happy': custom[0][3],
                    'sad': custom[0][4], 'surprise': custom[0][5], 'neutral': custom[0][6]}
        print(custom)
        print(max(custom[0]))
        print(emotion_analysis(custom[0]))
        if max(custom[0]) == emo_reff['angry']:
            angry += 1
        elif max(custom[0]) == emo_reff['disgust']:
            disgust += 1
        elif max(custom[0]) == emo_reff['fear']:
            fear += 1
        elif max(custom[0]) == emo_reff['happy']:
            happy += 1
        elif max(custom[0]) == emo_reff['sad']:
            sad += 1
        elif max(custom[0]) == emo_reff['surprise']:
            surprise += 1
        else:
            neutral += 1
            

        x = np.array(x, 'float32')
        x = x.reshape([48, 48]);

        plt.imshow(true_image)
        plt.show()
    except:
        print("Image doesn't exist")
        continue
        
#     ----------------------------------------------------------------------------------
#     file  = 'C:/Users/User/Desktop/test/angry_valid/capture355.jpg'
# #     print(photo_count)
#     true_image = image.load_img(file)
#     img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))


#     #  --------------------------------------------------------------------------------
#     x = image.img_to_array(img)
#     x = np.expand_dims(x, axis = 0)

#     x /= 255

#     custom = model.predict(x)
#     emotion_analysis(custom[0])
#     print(custom)
#     print(max(custom[0]))
#     print(emotion_analysis(custom[0]))

#     x = np.array(x, 'float32')
#     x = x.reshape([48, 48]);

#     plt.imshow(true_image)
#     plt.show()
# Out:
# 1
# Image doesn't exist
# 2
# Image doesn't exist
# 3
# Image doesn't exist
# 4
# Image doesn't exist
# 5
# [[4.7722736e-01 2.8392514e-02 7.8430675e-02 2.2150756e-05 9.1856636e-02
#   3.2395080e-01 1.1983143e-04]]
# 0.47722736
# None
# 6
# [[1.8647009e-01 1.9857225e-04 6.1663512e-02 1.3972203e-03 6.4002395e-01
#   1.0817526e-01 2.0713818e-03]]
# 0.64002395
# None
# 7
# Image doesn't exist
# 8
# [[1.8559459e-04 1.5650287e-06 6.2572062e-02 4.5134043e-03 9.2844713e-01
#   3.5085352e-03 7.7163562e-04]]
# 0.9284471
# None
# 9
# Image doesn't exist
# 10
# Image doesn't exist
# 11
# Image doesn't exist
# 12
# Image doesn't exist
# 13
# Image doesn't exist
# 14
# Image doesn't exist
# 15
# Image doesn't exist
# 16
# Image doesn't exist
# 17
# Image doesn't exist
# 18
# [[0.3375121  0.00066979 0.3508624  0.00080849 0.01521403 0.04060598
#   0.2543272 ]]
# 0.3508624
# None
# 19
# Image doesn't exist
# 20
# Image doesn't exist
# 21
# [[2.7505562e-04 4.8158009e-04 3.4476686e-02 9.1347158e-01 5.0851903e-03
#   4.6186138e-02 2.3790271e-05]]
# 0.9134716
# None
# 22
# Image doesn't exist
# 23
# Image doesn't exist
# 24
# Image doesn't exist
# 25
# Image doesn't exist
# 26
# Image doesn't exist
# 27
# Image doesn't exist
# 28
# [[6.6599287e-02 6.2846593e-03 7.1132749e-02 5.3869987e-01 2.3567293e-02
#   2.9337782e-01 3.3836023e-04]]
# 0.53869987
# None
# 29
# Image doesn't exist
# 30
# Image doesn't exist
# 31
# [[2.7475494e-01 1.1057420e-02 4.3234404e-02 2.5105011e-03 1.5076422e-02
#   6.5336627e-01 4.3973259e-08]]
# 0.65336627
# None
# 32
# Image doesn't exist
# 33
# Image doesn't exist
# 34
# Image doesn't exist
# 35
# Image doesn't exist
# 36
# Image doesn't exist
# 37
# Image doesn't exist
# 38
# Image doesn't exist
# 39
# [[0.22596547 0.25703573 0.23406112 0.007386   0.00250945 0.22853145
#   0.04451071]]
# 0.25703573
# None
# 40
# Image doesn't exist
# 41
# Image doesn't exist
# 42
# [[1.6947143e-01 3.1923114e-03 1.3222882e-01 2.7921199e-04 2.0476569e-01
#   4.8963505e-01 4.2742217e-04]]
# 0.48963505
# None
# 43
# Image doesn't exist
# 44
# Image doesn't exist
# 45
# Image doesn't exist
# 46
# Image doesn't exist
# 47
# Image doesn't exist
# 48
# Image doesn't exist
# 49
# Image doesn't exist
# 50
# Image doesn't exist
# 51
# [[6.2304135e-02 4.8331878e-04 1.9883345e-01 4.9279850e-05 3.4032784e-02
#   7.0424324e-01 5.3785479e-05]]
# 0.70424324
# None
# 52
# [[4.4535656e-02 4.0640164e-04 3.8005862e-02 2.0175636e-01 2.7385654e-02
#   6.8617451e-01 1.7356192e-03]]
# 0.6861745
# None
# 53
# Image doesn't exist
# 54
# Image doesn't exist
# 55
# Image doesn't exist
# 56
# Image doesn't exist
# 57
# [[2.6345650e-02 6.2089856e-04 1.4165238e-01 1.1844123e-04 7.8876692e-01
#   1.8221591e-02 2.4274155e-02]]
# 0.7887669
# None
# 58
# Image doesn't exist
# 59
# Image doesn't exist
# 60
# Image doesn't exist
# 61
# [[5.9719434e-05 2.4343544e-06 8.9215720e-01 4.8090864e-02 2.6306591e-04
#   1.0244032e-02 4.9182698e-02]]
# 0.8921572
# None
# 62
# Image doesn't exist
# 63
# Image doesn't exist
# 64
# Image doesn't exist
# 65
# Image doesn't exist
# 66
# Image doesn't exist
# 67
# Image doesn't exist
# 68
# Image doesn't exist
# 69
# [[0.17539361 0.03232057 0.2857357  0.00151717 0.01825011 0.48616558
#   0.00061729]]
# 0.48616558
# None
# 70
# [[0.24676514 0.00555704 0.07674754 0.00127208 0.07099089 0.5657613
#   0.03290596]]
# 0.5657613
# None
# 71
# Image doesn't exist
# 72
# Image doesn't exist
# 73
# [[5.2430391e-02 2.9035637e-03 9.0057869e-03 1.2643365e-03 7.1710205e-01
#   2.1714903e-01 1.4478705e-04]]
# 0.71710205
# None
# 74
# Image doesn't exist
# 75
# Image doesn't exist
# 76
# [[0.04136949 0.00593985 0.07347949 0.02031325 0.04362781 0.8130858
#   0.00218421]]
# 0.8130858
# None
# 77
# [[3.1948425e-02 4.9932639e-04 2.7942306e-03 1.3852081e-01 6.1823773e-01
#   2.0798633e-01 1.3104732e-05]]
# 0.61823773
# None
# 78
# Image doesn't exist
# 79
# [[7.2109386e-02 4.3201741e-02 8.8458017e-02 1.3576263e-03 1.7921407e-02
#   7.7690458e-01 4.7198322e-05]]
# 0.7769046
# None
# 80
# Image doesn't exist
# 81
# Image doesn't exist
# 82
# Image doesn't exist
# 83
# Image doesn't exist
# 84
# [[1.1523515e-02 3.8727952e-04 3.9753232e-02 3.0086207e-04 1.2207517e-01
#   8.2590407e-01 5.5798522e-05]]
# 0.8259041
# None
# 85
# Image doesn't exist
# 86
# Image doesn't exist
# 87
# Image doesn't exist
# 88
# Image doesn't exist
# 89
# Image doesn't exist
# 90
# [[3.8687421e-03 1.3158349e-07 9.8884928e-01 8.6540740e-06 9.0935168e-07
#   7.1888701e-03 8.3559011e-05]]
# 0.9888493
# None
# 91
# [[2.5655461e-02 1.0884412e-03 4.0429819e-01 5.5807331e-03 4.6848550e-02
#   5.1645720e-01 7.1493960e-05]]
# 0.5164572
# None
# 92
# [[6.4939907e-04 1.0352192e-05 4.5641181e-01 3.4612196e-04 1.8849649e-01
#   3.5400578e-01 7.9954385e-05]]
# 0.4564118
# None
# 93
# [[3.8481292e-01 8.5234381e-03 1.3259906e-01 1.0390924e-02 2.0694930e-02
#   4.4275099e-01 2.2777166e-04]]
# 0.442751
# None
# 94
# [[0.412609   0.00491768 0.26350132 0.00182721 0.13175252 0.18138874
#   0.00400349]]
# 0.412609
# None
# 95
# [[6.2509000e-02 1.8732721e-06 9.1186836e-02 8.3781837e-05 7.4537367e-02
#   7.7167779e-01 3.3750944e-06]]
# 0.7716778
# None
# 96
# Image doesn't exist
# 97
# [[0.0166052  0.0010391  0.24876365 0.00324439 0.06844537 0.6593226
#   0.00257961]]
# 0.6593226
# None
# 98
# [[0.2189966  0.00726454 0.23233406 0.02024042 0.04449015 0.39488083
#   0.08179342]]
# 0.39488083
# None
# 99
# Image doesn't exist
# 100
# Image doesn't exist
# 101
# Image doesn't exist
# 102
# Image doesn't exist
# 103
# Image doesn't exist
# 104
# [[5.8418464e-02 8.8431610e-05 3.1637054e-02 7.0782267e-02 5.6891453e-02
#   7.8174335e-01 4.3894732e-04]]
# 0.78174335
# None
# 105
# Image doesn't exist
# 106
# Image doesn't exist
# 107
# Image doesn't exist
# 108
# Image doesn't exist
# 109
# [[5.4942229e-06 7.5987122e-10 5.6953821e-03 3.8211976e-04 9.0674031e-01
#   1.7491399e-03 8.5427634e-02]]
# 0.9067403
# None
# 110
# Image doesn't exist
# 111
# Image doesn't exist
# 112
# [[9.8947376e-01 4.5141988e-03 2.5587450e-03 2.5089968e-05 1.2376468e-04
#   3.2566753e-03 4.7821679e-05]]
# 0.98947376
# None
# 113
# Image doesn't exist
# 114
# [[1.8736627e-02 4.5031766e-04 3.8627326e-02 8.8570750e-06 3.1905424e-02
#   9.1023564e-01 3.5758720e-05]]
# 0.91023564
# None
# 115
# Image doesn't exist
# 116
# Image doesn't exist
# 117
# Image doesn't exist
# 118
# Image doesn't exist
# 119
# Image doesn't exist
# 120
# Image doesn't exist
# 121
# Image doesn't exist
# 122
# Image doesn't exist
# 123
# [[1.2170937e-03 5.7336834e-05 9.6224225e-04 7.0514550e-05 9.9611843e-01
#   1.4610760e-03 1.1329300e-04]]
# 0.9961184
# None
# 124
# [[3.3365894e-02 9.5003366e-04 9.3013935e-02 4.6260998e-04 2.5011671e-01
#   6.1452758e-01 7.5632562e-03]]
# 0.6145276
# None
# 125
# [[1.3762675e-04 1.0087903e-06 1.7325419e-03 2.3531772e-03 8.0298306e-03
#   9.8739737e-01 3.4843682e-04]]
# 0.9873974
# None
# 126
# Image doesn't exist
# 127
# [[6.2397571e-04 9.9209446e-06 5.3220923e-04 1.3035938e-05 1.1946039e-03
#   9.9761701e-01 9.3038634e-06]]
# 0.997617
# None
# 128
# Image doesn't exist
# 129
# Image doesn't exist
# 130
# Image doesn't exist
# 131
# Image doesn't exist
# 132
# [[1.8011978e-01 1.8472749e-05 2.2544920e-01 5.5259153e-07 1.7749768e-01
#   4.1690487e-01 9.4386287e-06]]
# 0.41690487
# None
# 133
# Image doesn't exist
# 134
# Image doesn't exist
# 135
# Image doesn't exist
# 136
# Image doesn't exist
# 137
# [[0.363095   0.00625001 0.26704735 0.11737607 0.03347769 0.18088554
#   0.03186836]]
# 0.363095
# None
# 138
# [[6.2429869e-01 2.0133732e-05 7.5090870e-02 4.5297183e-03 4.0530477e-02
#   2.5003013e-01 5.4999245e-03]]
# 0.6242987
# None
# 139
# Image doesn't exist
# 140
# Image doesn't exist
# 141
# Image doesn't exist
# 142
# Image doesn't exist
# 143
# Image doesn't exist
# 144
# Image doesn't exist
# 145
# Image doesn't exist
# 146
# Image doesn't exist
# 147
# Image doesn't exist
# 148
# Image doesn't exist
# 149
# Image doesn't exist
# 150
# Image doesn't exist
# 151
# [[1.7834313e-01 3.5320017e-02 2.6619747e-01 1.7245875e-04 7.2189525e-02
#   4.4776899e-01 8.4144285e-06]]
# 0.447769
# None
# 152
# [[7.9458049e-03 1.9575744e-04 1.2581410e-02 8.0265440e-03 2.0116453e-01
#   7.7006006e-01 2.5884685e-05]]
# 0.77006006
# None
# 153
# Image doesn't exist
# 154
# Image doesn't exist
# 155
# Image doesn't exist
# 156
# Image doesn't exist
# 157
# Image doesn't exist
# 158
# Image doesn't exist
# 159
# Image doesn't exist
# 160
# [[6.0333451e-03 7.1490481e-06 3.1400505e-01 2.5981393e-07 1.8375000e-01
#   4.9612692e-01 7.7284567e-05]]
# 0.49612692
# None
# 161
# Image doesn't exist
# 162
# [[5.4636914e-02 1.2693142e-03 4.1735530e-01 3.5318127e-04 2.4263571e-01
#   2.8263620e-01 1.1134214e-03]]
# 0.4173553
# None
# 163
# Image doesn't exist
# 164
# Image doesn't exist
# 165
# [[0.01533121 0.08408348 0.08351608 0.00440217 0.20329323 0.60868126
#   0.00069256]]
# 0.60868126
# None
# 166
# Image doesn't exist
# 167
# Image doesn't exist
# 168
# [[4.7379214e-01 2.3260391e-05 7.5647354e-02 7.2703010e-04 3.8811511e-01
#   6.1681874e-02 1.3184528e-05]]
# 0.47379214
# None
# 169
# [[7.5689494e-04 1.7090350e-04 1.3982723e-02 4.3234408e-02 5.8310560e-04
#   9.3787909e-01 3.3929346e-03]]
# 0.9378791
# None
# 170
# Image doesn't exist
# 171
# [[4.6771248e-03 3.3972738e-05 8.5419846e-01 3.7024166e-03 1.9299813e-03
#   7.9595216e-02 5.5862948e-02]]
# 0.85419846
# None
# 172
# Image doesn't exist
# 173
# Image doesn't exist
# 174
# Image doesn't exist
# 175
# Image doesn't exist
# 176
# [[9.9984277e-03 1.3664885e-05 6.9057189e-02 1.1238646e-02 8.7976986e-01
#   2.9627485e-02 2.9484351e-04]]
# 0.87976986
# None
# 177
# Image doesn't exist
# 178
# [[2.9856896e-02 3.6999551e-03 5.7922894e-01 1.9269735e-06 2.5598526e-03
#   3.8172609e-01 2.9263166e-03]]
# 0.57922894
# None
# 179
# Image doesn't exist
# 180
# [[0.21641213 0.15749355 0.08579127 0.00696218 0.25052482 0.2748364
#   0.00797971]]
# 0.2748364
# None
# 181
# Image doesn't exist
# 182
# Image doesn't exist
# 183
# Image doesn't exist
# 184
# [[0.13777758 0.4981355  0.05915937 0.00984369 0.00408427 0.27636126
#   0.0146384 ]]
# 0.4981355
# None
# 185
# [[0.09527072 0.00266057 0.27661943 0.02140669 0.44474652 0.15491243
#   0.00438356]]
# 0.44474652
# None
# 186
# [[0.05642151 0.00109412 0.07476714 0.00455953 0.41979647 0.428739
#   0.01462229]]
# 0.428739
# None
# 187
# Image doesn't exist
# 188
# Image doesn't exist
# 189
# [[1.3614423e-03 1.8212109e-05 4.2293705e-02 2.3735235e-04 3.1853592e-04
#   9.5571631e-01 5.4457978e-05]]
# 0.9557163
# None
# 190
# Image doesn't exist
# 191
# Image doesn't exist
# 192
# Image doesn't exist
# 193
# Image doesn't exist
# 194
# Image doesn't exist
# 195
# Image doesn't exist
# 196
# Image doesn't exist
# 197
# Image doesn't exist
# 198
# Image doesn't exist
# 199
# Image doesn't exist
# 200
# Image doesn't exist
# 201
# Image doesn't exist
# 202
# Image doesn't exist
# 203
# [[3.4355395e-02 4.4620524e-06 5.9814058e-02 2.4217942e-04 3.8807806e-01
#   5.1697946e-01 5.2636984e-04]]
# 0.51697946
# None
# 204
# Image doesn't exist
# 205
# [[1.08608246e-01 5.20197558e-04 1.04320608e-01 3.45980525e-01
#   7.29003996e-02 3.67504686e-01 1.65360296e-04]]
# 0.3675047
# None
# 206
# Image doesn't exist
# 207
# [[0.42256132 0.02256416 0.22051395 0.00171671 0.09174424 0.11356952
#   0.12733005]]
# 0.42256132
# None
# 208
# Image doesn't exist
# 209
# Image doesn't exist
# 210
# Image doesn't exist
# 211
# Image doesn't exist
# 212
# [[1.9826733e-03 3.6270663e-07 6.0844970e-01 2.3117892e-02 5.3599194e-02
#   4.9347974e-02 2.6350224e-01]]
# 0.6084497
# None
# 213
# Image doesn't exist
# 214
# [[4.7058556e-03 9.1470797e-03 7.0061736e-02 6.2902108e-02 6.5238096e-02
#   7.8785640e-01 8.8770073e-05]]
# 0.7878564
# None
# 215
# Image doesn't exist
# 216
# [[5.6943071e-01 1.8352388e-04 2.1636037e-02 7.8795641e-04 2.4689475e-01
#   1.6099602e-01 7.0939546e-05]]
# 0.5694307
# None
# 217
# Image doesn't exist
# 218
# Image doesn't exist
# 219
# Image doesn't exist
# 220
# Image doesn't exist
# 221
# Image doesn't exist
# 222
# Image doesn't exist
# 223
# Image doesn't exist
# 224
# [[0.01854724 0.00115997 0.26392913 0.00130552 0.59733295 0.11342699
#   0.00429813]]
# 0.59733295
# None
# 225
# [[0.10631566 0.13501391 0.32094255 0.03504077 0.19565834 0.20043641
#   0.00659232]]
# 0.32094255
# None
# 226
# Image doesn't exist
# 227
# Image doesn't exist
# 228
# Image doesn't exist
# 229
# Image doesn't exist
# 230
# Image doesn't exist
# 231
# Image doesn't exist
# 232
# Image doesn't exist
# 233
# Image doesn't exist
# 234
# Image doesn't exist
# 235
# Image doesn't exist
# 236
# Image doesn't exist
# 237
# Image doesn't exist
# 238
# [[5.7742227e-02 2.4589956e-06 1.6681248e-02 1.2173997e-03 5.5020517e-01
#   3.7404951e-01 1.0198062e-04]]
# 0.5502052
# None
# 239
# Image doesn't exist
# 240
# Image doesn't exist
# 241
# Image doesn't exist
# 242
# Image doesn't exist
# 243
# Image doesn't exist
# 244
# Image doesn't exist
# 245
# [[0.06495003 0.00284338 0.01260516 0.70846957 0.02017417 0.18301994
#   0.00793774]]
# 0.70846957
# None
# 246
# [[0.09292361 0.01007985 0.07710204 0.10218301 0.48480257 0.2182072
#   0.01470172]]
# 0.48480257
# None
# 247
# Image doesn't exist
# 248
# Image doesn't exist
# 249
# [[3.7564395e-04 8.6721735e-07 4.5877319e-02 1.5413582e-02 7.6153692e-06
#   9.3830740e-01 1.7577924e-05]]
# 0.9383074
# None
# 250
# Image doesn't exist
# 251
# Image doesn't exist
# 252
# [[2.1172303e-01 5.9242098e-04 2.4603028e-02 1.4587098e-03 4.5797783e-03
#   7.5701922e-01 2.3857721e-05]]
# 0.7570192
# None
# 253
# Image doesn't exist
# 254
# [[0.05327233 0.00506845 0.13012077 0.01569305 0.30436724 0.4883631
#   0.00311509]]
# 0.4883631
# None
# 255
# Image doesn't exist
# 256
# [[1.13504597e-04 8.74983452e-05 7.53161237e-02 8.88832092e-01
#   9.14060452e-04 3.46235670e-02 1.13086455e-04]]
# 0.8888321
# None
# 257
# Image doesn't exist
# 258
# Image doesn't exist
# 259
# [[9.3735725e-01 4.4087440e-04 4.0408382e-03 1.6354551e-04 4.2603584e-03
#   5.3640187e-02 9.6988289e-05]]
# 0.93735725
# None
# 260
# [[7.7448990e-03 2.9461939e-04 6.2278346e-03 1.1094567e-04 9.6197790e-01
#   2.3157669e-02 4.8612754e-04]]
# 0.9619779
# None
# 261
# Image doesn't exist
# 262
# Image doesn't exist
# 263
# Image doesn't exist
# 264
# Image doesn't exist
# 265
# Image doesn't exist
# 266
# Image doesn't exist
# 267
# Image doesn't exist
# 268
# [[0.17268726 0.00372173 0.260598   0.00055537 0.34766653 0.21266139
#   0.00210971]]
# 0.34766653
# None
# 269
# Image doesn't exist
# 270
# Image doesn't exist
# 271
# Image doesn't exist
# 272
# [[0.01230124 0.00141927 0.06600191 0.00777536 0.18901484 0.7014834
#   0.02200399]]
# 0.7014834
# None
# 273
# Image doesn't exist
# 274
# [[8.2949856e-03 5.0522969e-04 5.3558643e-03 4.3358676e-05 2.6576187e-02
#   9.4552904e-01 1.3695331e-02]]
# 0.94552904
# None
# 275
# [[0.22773217 0.00756998 0.5356175  0.00075755 0.01258408 0.00723859
#   0.20850024]]
# 0.5356175
# None
# 276
# Image doesn't exist
# 277
# [[5.7330052e-03 9.1451703e-04 1.1228689e-01 2.2356011e-02 3.8411398e-03
#   8.5458523e-01 2.8311214e-04]]
# 0.85458523
# None
# 278
# Image doesn't exist
# 279
# [[3.0289832e-01 3.1423792e-02 1.5015182e-01 6.4803200e-05 1.3283741e-01
#   3.8242099e-01 2.0294019e-04]]
# 0.382421
# None
# 280
# Image doesn't exist
# 281
# Image doesn't exist
# 282
# [[1.1214351e-02 1.3501332e-03 7.8587597e-03 3.7587892e-02 1.4174505e-02
#   9.2709720e-01 7.1722578e-04]]
# 0.9270972
# None
# 283
# Image doesn't exist
# 284
# Image doesn't exist
# 285
# Image doesn't exist
# 286
# Image doesn't exist
# 287
# [[6.0816830e-01 8.5466066e-03 4.1204982e-02 9.1383103e-05 7.5052507e-02
#   2.6693356e-01 2.7114108e-06]]
# 0.6081683
# None
# 288
# Image doesn't exist
# 289
# Image doesn't exist
# 290
# [[2.7365144e-02 1.7306802e-05 6.2787966e-03 2.9619974e-03 2.3040574e-03
#   9.6102297e-01 4.9682632e-05]]
# 0.961023
# None
# 291
# Image doesn't exist
# 292
# Image doesn't exist
# 293
# Image doesn't exist
# 294
# Image doesn't exist
# 295
# [[3.4525845e-02 1.4411104e-03 1.3483998e-01 1.0351384e-03 6.1440688e-01
#   2.1321414e-01 5.3693313e-04]]
# 0.6144069
# None
# 296
# Image doesn't exist
# 297
# Image doesn't exist
# 298
# Image doesn't exist
# 299
# Image doesn't exist
# 300
# Image doesn't exist
# 301
# Image doesn't exist
# 302
# [[8.7666931e-03 1.5889795e-04 4.5304608e-02 1.8901541e-05 8.9599099e-03
#   9.3649989e-01 2.9106869e-04]]
# 0.9364999
# None
# 303
# [[4.4731799e-04 2.9823363e-03 3.6843412e-03 2.3855412e-04 1.2570510e-04
#   9.9252021e-01 1.6737959e-06]]
# 0.9925202
# None
# 304
# Image doesn't exist
# 305
# Image doesn't exist
# 306
# Image doesn't exist
# 307
# [[5.48520982e-01 3.01610589e-01 4.91395928e-02 1.71409272e-06
#   1.23445615e-02 8.81187543e-02 2.63815338e-04]]
# 0.548521
# None
# 308
# Image doesn't exist
# 309
# Image doesn't exist
# 310
# Image doesn't exist
# 311
# Image doesn't exist
# 312
# Image doesn't exist
# 313
# [[6.4885341e-02 7.8070769e-04 7.2126210e-01 6.0954737e-04 1.8505245e-02
#   1.9373621e-01 2.2084914e-04]]
# 0.7212621
# None
# 314
# Image doesn't exist
# 315
# Image doesn't exist
# 316
# Image doesn't exist
# 317
# Image doesn't exist
# 318
# Image doesn't exist
# 319
# [[5.1830548e-01 4.6388466e-02 3.0805761e-01 2.7588584e-02 5.4318152e-02
#   4.5092609e-02 2.4915938e-04]]
# 0.5183055
# None
# 320
# Image doesn't exist
# 321
# Image doesn't exist
# 322
# Image doesn't exist
# 323
# Image doesn't exist
# 324
# [[2.5922418e-02 2.9371251e-05 1.6359447e-01 3.5951967e-07 3.6097351e-01
#   4.4555128e-01 3.9286120e-03]]
# 0.44555128
# None
# 325
# Image doesn't exist
# 326
# Image doesn't exist
# 327
# Image doesn't exist
# 328
# Image doesn't exist
# 329
# Image doesn't exist
# 330
# [[1.0249920e-01 1.0095156e-03 9.9997595e-02 2.9025332e-03 3.8396727e-02
#   7.5488371e-01 3.1073377e-04]]
# 0.7548837
# None
# 331
# Image doesn't exist
# 332
# Image doesn't exist
# 333
# [[5.4734331e-02 4.2432290e-05 3.8157697e-03 2.5576490e-03 4.4277787e-02
#   8.9352065e-01 1.0512909e-03]]
# 0.89352065
# None
# 334
# [[0.07027902 0.00703646 0.02714204 0.00599616 0.8776123  0.00944667
#   0.00248744]]
# 0.8776123
# None
# 335
# [[1.3778548e-02 1.1246495e-03 4.5400643e-01 6.0057635e-05 2.0099904e-01
#   3.3002219e-01 9.1334523e-06]]
# 0.45400643
# None
# 336
# Image doesn't exist

# %%
print("angry =", angry)
print("disgust =", disgust)
print("fear =", fear)
print("happy =", happy)
print("sad =", sad)
print("surprise =", surprise)
print("neutral =", neutral)
print("\n")

total = angry + disgust + fear + happy + sad + surprise + neutral
print("Total =", total)

print("sad precentage % =", (sad/total) *100)
# Out:
# angry = 12
# disgust = 2
# fear = 12
# happy = 4
# sad = 16
# surprise = 45
# neutral = 0
#
#
# Total = 91
# sad precentage % = 17.582417582417584
