# %%
from itertools import count
import numpy as np
import argparse
import cv2
from PIL import ImageGrab
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import csv
import time
import socket
from imutils.video import VideoStream
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import pandas
from sklearn import model_selection
# from sklearn.linear_model import LogisticRegression
import joblib
import pandas as pd

model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

model.load_weights('C:/Users/User/Desktop/ERS/model.h5')

# %%
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
#     objects = ('angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
import cv2
import os
import numpy as np
import torch

# input folder
folder='C:/Users/User/Desktop/test/fearful'

images = []
# for filename in os.listdir(folder):
#     img = cv2.imread(os.path.join(folder,filename))

#     if img is not None:
#         images.append(img)
        
# print(images)
def facecrop(image):  
    facedata = 'C:/Users/User/Desktop/ERS/haar cascade files/haarcascade_frontalface_default.xml'
    cascade = cv2.CascadeClassifier(facedata)
    img_num = 0
    
    for filename in os.listdir(folder):
        img_num += 1
        img = cv2.imread(os.path.join(folder,filename))
        
        if img is not None:
            images.append(img)

        try:

            minisize = (img.shape[1],img.shape[0])
            miniframe = cv2.resize(img, minisize)

            faces = cascade.detectMultiScale(miniframe)

            for f in faces:
                x, y, w, h = [ v for v in f ]
                cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

                sub_face = img[y:y+h, x:x+w]

                # images output folder
                cv2.imwrite('C:/Users/User/Desktop/test/fearful_valid/capture{0}.jpg'.format(img_num), sub_face)
                #print ("Writing: " + image)

        except Exception as e:
            print (e)

   

if __name__ == '__main__':
    # first image to start looping 
    facecrop('C:/Users/User/Desktop/test/fearful/im0.png')
#Testing a file.


# Redo comment below
# ------------------------------------------------------------------------------------------

# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import spicy as sc
from scipy import misc


folder_valid = 'C:/Users/User/Desktop/test/fearful_valid'
# 'C:/Users/User/Desktop/test/angry_valid/capture  {0}.jpg'
all_vald_img = []
photo_count = 0
angry = 0
disgust = 0
fear = 0
happy = 0
sad = 0
surprise = 0
neutral = 0
    
for filename_valid in os.listdir(folder_valid):
    photo_count += 1
    img_valid = cv2.imread(os.path.join(folder_valid,filename_valid))
    if img_valid is not None:
        all_vald_img.append(img_valid)

# print(all_vald_img)

# print(len(all_vald_img))
#     if photo_count == len(all_vald_img):
#         pass
    try:
        file  = 'C:/Users/User/Desktop/test/fearful_valid/capture{0}.jpg'.format(photo_count)
        print(photo_count)
        true_image = image.load_img(file)
        img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))


        #  --------------------------------------------------------------------------------
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis = 0)

        x /= 255

        custom = model.predict(x)
        emotion_analysis(custom[0])
        emo_reff = {'angry': custom[0][0], 'disgust': custom[0][1], 'fear': custom[0][2], 'happy': custom[0][3],
                    'sad': custom[0][4], 'surprise': custom[0][5], 'neutral': custom[0][6]}
        print(custom)
        print(max(custom[0]))
        print(emotion_analysis(custom[0]))
        if max(custom[0]) == emo_reff['angry']:
            angry += 1
        elif max(custom[0]) == emo_reff['disgust']:
            disgust += 1
        elif max(custom[0]) == emo_reff['fear']:
            fear += 1
        elif max(custom[0]) == emo_reff['happy']:
            happy += 1
        elif max(custom[0]) == emo_reff['sad']:
            sad += 1
        elif max(custom[0]) == emo_reff['surprise']:
            surprise += 1
        else:
            neutral += 1
            

        x = np.array(x, 'float32')
        x = x.reshape([48, 48]);

        plt.imshow(true_image)
        plt.show()
    except:
        print("Image doesn't exist")
        continue
        
#     ----------------------------------------------------------------------------------
#     file  = 'C:/Users/User/Desktop/test/angry_valid/capture355.jpg'
# #     print(photo_count)
#     true_image = image.load_img(file)
#     img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))


#     #  --------------------------------------------------------------------------------
#     x = image.img_to_array(img)
#     x = np.expand_dims(x, axis = 0)

#     x /= 255

#     custom = model.predict(x)
#     emotion_analysis(custom[0])
#     print(custom)
#     print(max(custom[0]))
#     print(emotion_analysis(custom[0]))

#     x = np.array(x, 'float32')
#     x = x.reshape([48, 48]);

#     plt.imshow(true_image)
#     plt.show()
# Out:
# 1
# [[4.5197112e-03 6.0869269e-03 8.8613309e-02 8.4642857e-02 1.6544523e-03
#   8.1447577e-01 6.9318958e-06]]
# 0.8144758
# None
# 2
# Image doesn't exist
# 3
# Image doesn't exist
# 4
# [[2.9636985e-03 4.2714451e-08 7.0021713e-01 2.8908772e-03 3.9345730e-02
#   7.7022336e-02 1.7756018e-01]]
# 0.7002171
# None
# 5
# [[0.25093877 0.01032612 0.14674725 0.00211525 0.01248198 0.57629037
#   0.00110027]]
# 0.57629037
# None
# 6
# [[6.1395409e-04 3.8454922e-07 9.7945857e-01 8.6829308e-03 2.7197658e-04
#   8.8654626e-03 2.1067243e-03]]
# 0.9794586
# None
# 7
# [[2.6051060e-04 2.9446093e-05 2.2125376e-02 5.7351653e-02 2.1841167e-03
#   9.1750610e-01 5.4286578e-04]]
# 0.9175061
# None
# 8
# [[3.0443776e-01 4.5723096e-03 2.7498683e-01 1.0027167e-07 6.5158107e-03
#   4.0942791e-01 5.9204056e-05]]
# 0.4094279
# None
# 9
# Image doesn't exist
# 10
# Image doesn't exist
# 11
# [[0.20808333 0.00411972 0.37068865 0.07425519 0.01790212 0.2778198
#   0.04713109]]
# 0.37068865
# None
# 12
# [[0.06744014 0.004814   0.5155463  0.00346216 0.06177713 0.31417614
#   0.03278406]]
# 0.5155463
# None
# 13
# Image doesn't exist
# 14
# [[4.7610405e-01 5.1399136e-01 9.5477775e-03 4.0373807e-09 3.8242659e-05
#   3.1852399e-04 2.9740963e-08]]
# 0.51399136
# None
# 15
# Image doesn't exist
# 16
# Image doesn't exist
# 17
# [[0.01171776 0.00120979 0.7196315  0.00215894 0.08212788 0.15978017
#   0.02337401]]
# 0.7196315
# None
# 18
# Image doesn't exist
# 19
# Image doesn't exist
# 20
# Image doesn't exist
# 21
# Image doesn't exist
# 22
# [[1.3586327e-02 4.6955957e-04 8.1651175e-01 3.8929280e-05 9.6224602e-03
#   1.7666377e-02 1.4210463e-01]]
# 0.81651175
# None
# 23
# [[2.6347315e-01 3.7096441e-05 2.4675217e-02 2.7738650e-05 6.6837120e-01
#   8.1109311e-03 3.5304606e-02]]
# 0.6683712
# None
# 24
# Image doesn't exist
# 25
# Image doesn't exist
# 26
# Image doesn't exist
# 27
# [[0.19848838 0.05102136 0.03794974 0.08037131 0.5846129  0.04238015
#   0.00517611]]
# 0.5846129
# None
# 28
# Image doesn't exist
# 29
# Image doesn't exist
# 30
# [[0.11900968 0.01833435 0.0967731  0.02152071 0.2796758  0.46204114
#   0.00264519]]
# 0.46204114
# None
# 31
# Image doesn't exist
# 32
# [[6.0131498e-07 4.7583743e-10 9.9952459e-01 4.3583218e-06 1.8619106e-06
#   4.6322981e-04 5.3472099e-06]]
# 0.9995246
# None
# 33
# Image doesn't exist
# 34
# [[7.7136256e-02 6.6977274e-04 4.3450704e-01 4.0332532e-05 4.2994164e-02
#   4.1620347e-01 2.8448943e-02]]
# 0.43450704
# None
# 35
# Image doesn't exist
# 36
# Image doesn't exist
# 37
# Image doesn't exist
# 38
# Image doesn't exist
# 39
# Image doesn't exist
# 40
# Image doesn't exist
# 41
# Image doesn't exist
# 42
# Image doesn't exist
# 43
# [[1.4735752e-01 2.1626442e-04 4.5437920e-01 2.5541177e-03 1.8823938e-01
#   1.7845966e-01 2.8793914e-02]]
# 0.4543792
# None
# 44
# Image doesn't exist
# 45
# [[5.4026034e-02 2.4393877e-02 2.6234707e-01 1.6948602e-06 1.9931433e-01
#   4.3360487e-01 2.6312105e-02]]
# 0.43360487
# None
# 46
# Image doesn't exist
# 47
# Image doesn't exist
# 48
# Image doesn't exist
# 49
# [[9.6167994e-01 3.4823511e-03 1.5102376e-02 2.8014785e-05 4.0021092e-03
#   1.2130028e-02 3.5752913e-03]]
# 0.96167994
# None
# 50
# Image doesn't exist
# 51
# Image doesn't exist
# 52
# Image doesn't exist
# 53
# [[1.7295378e-08 2.7782920e-11 1.7586971e-02 9.8761129e-06 1.2993536e-07
#   9.2459823e-07 9.8240215e-01]]
# 0.98240215
# None
# 54
# Image doesn't exist
# 55
# Image doesn't exist
# 56
# [[1.09676264e-04 2.14890861e-09 9.36318040e-01 2.61550372e-06
#   2.55471127e-06 1.12699463e-05 6.35558441e-02]]
# 0.93631804
# None
# 57
# Image doesn't exist
# 58
# Image doesn't exist
# 59
# Image doesn't exist
# 60
# Image doesn't exist
# 61
# Image doesn't exist
# 62
# Image doesn't exist
# 63
# Image doesn't exist
# 64
# Image doesn't exist
# 65
# [[0.01248708 0.01714121 0.10939329 0.35060772 0.01142931 0.27472162
#   0.22421974]]
# 0.35060772
# None
# 66
# Image doesn't exist
# 67
# [[1.3080718e-02 3.1436095e-04 5.7856152e-03 1.6548242e-02 2.3526659e-04
#   9.6359223e-01 4.4364104e-04]]
# 0.96359223
# None
# 68
# [[2.5307166e-04 4.9747847e-04 5.7275463e-02 1.0315600e-03 8.6311763e-04
#   7.6963683e-05 9.4000244e-01]]
# 0.94000244
# None
# 69
# [[2.0982791e-01 5.7999484e-02 5.4914242e-01 1.0607308e-04 6.1655860e-02
#   8.7652855e-02 3.3615422e-02]]
# 0.5491424
# None
# 70
# [[6.0131498e-07 4.7583743e-10 9.9952459e-01 4.3583218e-06 1.8619106e-06
#   4.6322981e-04 5.3472099e-06]]
# 0.9995246
# None
# 71
# Image doesn't exist
# 72
# Image doesn't exist
# 73
# Image doesn't exist
# 74
# [[1.3432531e-01 4.3668924e-04 8.6435717e-01 3.1373018e-09 5.7503523e-05
#   8.2080136e-04 2.4629041e-06]]
# 0.8643572
# None
# 75
# Image doesn't exist
# 76
# Image doesn't exist
# 77
# Image doesn't exist
# 78
# Image doesn't exist
# 79
# Image doesn't exist
# 80
# Image doesn't exist
# 81
# Image doesn't exist
# 82
# [[1.69583410e-02 1.96804365e-04 7.73444295e-01 3.27053480e-02
#   6.34836592e-03 1.70243204e-01 1.03653845e-04]]
# 0.7734443
# None
# 83
# Image doesn't exist
# 84
# [[7.67420745e-03 5.42211928e-04 1.15078881e-01 1.12343244e-01
#   2.90885419e-01 4.73454326e-01 2.16979915e-05]]
# 0.47345433
# None
# 85
# Image doesn't exist
# 86
# Image doesn't exist
# 87
# Image doesn't exist
# 88
# Image doesn't exist
# 89
# Image doesn't exist
# 90
# Image doesn't exist
# 91
# Image doesn't exist
# 92
# Image doesn't exist
# 93
# Image doesn't exist
# 94
# Image doesn't exist
# 95
# [[9.5616346e-03 6.0014543e-04 2.8056598e-03 1.8270386e-04 9.5417589e-01
#   3.2466073e-02 2.0798050e-04]]
# 0.9541759
# None
# 96
# Image doesn't exist
# 97
# [[2.5876497e-03 3.5763460e-07 8.6720228e-01 4.8305793e-07 9.1192042e-03
#   1.0333040e-01 1.7759657e-02]]
# 0.8672023
# None
# 98
# Image doesn't exist
# 99
# Image doesn't exist
# 100
# Image doesn't exist
# 101
# Image doesn't exist
# 102
# [[1.5663618e-03 3.5956930e-07 8.0301464e-01 1.5687017e-01 1.1209929e-02
#   2.2001572e-02 5.3369193e-03]]
# 0.80301464
# None
# 103
# Image doesn't exist
# 104
# Image doesn't exist
# 105
# Image doesn't exist
# 106
# Image doesn't exist
# 107
# Image doesn't exist
# 108
# Image doesn't exist
# 109
# [[8.7248668e-02 1.3159700e-05 3.9317526e-02 2.3609972e-01 2.5603434e-01
#   3.8122648e-01 6.0090009e-05]]
# 0.38122648
# None
# 110
# Image doesn't exist
# 111
# [[6.8745099e-02 1.8040375e-05 2.4547593e-01 7.5162239e-02 3.4571469e-01
#   2.6378378e-01 1.1001903e-03]]
# 0.3457147
# None
# 112
# Image doesn't exist
# 113
# Image doesn't exist
# 114
# Image doesn't exist
# 115
# Image doesn't exist
# 116
# [[9.3059078e-02 5.8254165e-05 1.3359535e-01 3.2408824e-04 3.1453294e-01
#   4.1617846e-01 4.2251829e-02]]
# 0.41617846
# None
# 117
# [[3.8013583e-01 5.7681481e-04 1.8049745e-01 4.3991618e-06 1.7477158e-01
#   2.6383120e-01 1.8276264e-04]]
# 0.38013583
# None
# 118
# [[0.02006965 0.00051239 0.32237968 0.07639892 0.09692181 0.48291865
#   0.00079893]]
# 0.48291865
# None
# 119
# Image doesn't exist
# 120
# Image doesn't exist
# 121
# Image doesn't exist
# 122
# Image doesn't exist
# 123
# Image doesn't exist
# 124
# Image doesn't exist
# 125
# [[3.23478758e-01 1.55921951e-02 7.68887401e-02 2.35449625e-06
#   4.80837703e-01 1.03174895e-01 2.53392336e-05]]
# 0.4808377
# None
# 126
# [[3.0589197e-03 2.9034123e-05 8.4532773e-01 3.2167973e-03 1.5224659e-02
#   1.3311788e-01 2.5015233e-05]]
# 0.84532773
# None
# 127
# Image doesn't exist
# 128
# Image doesn't exist
# 129
# [[2.29712910e-04 1.32634905e-05 9.92303133e-01 1.46171567e-06
#   5.59875332e-07 1.14101637e-03 6.31096354e-03]]
# 0.99230313
# None
# 130
# Image doesn't exist
# 131
# Image doesn't exist
# 132
# Image doesn't exist
# 133
# Image doesn't exist
# 134
# [[0.02123156 0.00423233 0.3535698  0.01881408 0.006856   0.09306811
#   0.50222814]]
# 0.50222814
# None
# 135
# Image doesn't exist
# 136
# Image doesn't exist
# 137
# Image doesn't exist
# 138
# Image doesn't exist
# 139
# Image doesn't exist
# 140
# Image doesn't exist
# 141
# Image doesn't exist
# 142
# [[0.03672726 0.00303434 0.03665603 0.35478336 0.5119652  0.05486053
#   0.00197331]]
# 0.5119652
# None
# 143
# [[1.4315994e-03 7.3241067e-06 4.1656863e-02 4.9680017e-05 4.7315385e-02
#   1.3441957e-02 8.9609724e-01]]
# 0.89609724
# None
# 144
# Image doesn't exist
# 145
# [[3.6009982e-02 3.9693718e-05 5.9284538e-01 1.5417833e-02 9.9370301e-02
#   1.5553634e-01 1.0078047e-01]]
# 0.5928454
# None
# 146
# [[0.22854567 0.03539728 0.3102961  0.13739698 0.01755913 0.20508522
#   0.06571963]]
# 0.3102961
# None
# 147
# [[1.53839409e-01 1.82580121e-03 1.24715105e-01 2.08597281e-04
#   4.08723429e-02 2.48824432e-02 6.53656304e-01]]
# 0.6536563
# None
# 148
# Image doesn't exist
# 149
# [[8.80337262e-04 3.56485951e-04 8.11844826e-01 6.78913125e-07
#   9.02182583e-05 1.14242295e-02 1.75403252e-01]]
# 0.8118448
# None
# 150
# [[2.2445252e-02 2.0655137e-03 1.6452565e-03 4.6244919e-01 4.4979489e-01
#   6.1599825e-02 5.1070273e-08]]
# 0.4624492
# None
# 151
# Image doesn't exist
# 152
# Image doesn't exist
# 153
# [[3.8929295e-02 1.7392002e-04 4.1232488e-01 1.1714378e-03 9.8111057e-05
#   4.0666881e-01 1.4063355e-01]]
# 0.41232488
# None
# 154
# Image doesn't exist
# 155
# Image doesn't exist
# 156
# [[1.4453826e-02 5.0943979e-04 2.2832343e-01 7.9623023e-03 3.8186546e-02
#   7.1027923e-01 2.8527289e-04]]
# 0.7102792
# None
# 157
# Image doesn't exist
# 158
# Image doesn't exist
# 159
# [[1.9156266e-03 2.7301491e-04 8.4929127e-01 1.2160460e-01 1.1536456e-02
#   1.3552163e-02 1.8268857e-03]]
# 0.84929127
# None
# 160
# [[4.6198692e-02 1.1688458e-04 2.7605429e-02 7.4237084e-01 1.0826602e-01
#   7.3931545e-02 1.5104560e-03]]
# 0.74237084
# None
# 161
# Image doesn't exist
# 162
# [[1.4212187e-01 4.4905385e-03 8.3017707e-01 3.8527169e-03 7.2532665e-04
#   1.8077971e-02 5.5455341e-04]]
# 0.83017707
# None
# 163
# [[3.4829997e-03 1.4051945e-04 9.8330870e-02 1.0010604e-02 3.2846215e-01
#   5.5838573e-01 1.1870953e-03]]
# 0.5583857
# None
# 164
# Image doesn't exist
# 165
# Image doesn't exist
# 166
# [[1.13763344e-04 4.68900282e-07 3.69219892e-02 7.44825287e-04
#   1.53033354e-03 2.42516297e-04 9.60446179e-01]]
# 0.9604462
# None
# 167
# Image doesn't exist
# 168
# Image doesn't exist
# 169
# Image doesn't exist
# 170
# Image doesn't exist
# 171
# [[0.12527679 0.00270056 0.50071377 0.25872776 0.00907499 0.00203959
#   0.10146651]]
# 0.50071377
# None
# 172
# Image doesn't exist
# 173
# Image doesn't exist
# 174
# Image doesn't exist
# 175
# Image doesn't exist
# 176
# Image doesn't exist
# 177
# [[6.4536512e-01 1.0252815e-02 8.9669801e-02 8.0265061e-05 7.9885954e-03
#   2.4664231e-01 1.1697223e-06]]
# 0.6453651
# None
# 178
# Image doesn't exist
# 179
# [[0.097675   0.0017323  0.11272737 0.00102593 0.4762601  0.31000683
#   0.00057252]]
# 0.4762601
# None
# 180
# [[0.03075433 0.00174358 0.11916565 0.00369227 0.00403893 0.04623021
#   0.794375  ]]
# 0.794375
# None
# 181
# Image doesn't exist
# 182
# Image doesn't exist
# 183
# [[7.8904835e-05 4.0298727e-04 9.8608297e-01 8.2094692e-07 3.6670035e-06
#   8.2331635e-03 5.1975213e-03]]
# 0.986083
# None
# 184
# [[1.6425014e-03 1.3963032e-06 2.0965980e-01 7.6312900e-01 1.4704639e-03
#   8.5906719e-04 2.3237813e-02]]
# 0.763129
# None
# 185
# [[0.01325822 0.00122073 0.810715   0.01904062 0.03889216 0.03586148
#   0.08101168]]
# 0.810715
# None
# 186
# Image doesn't exist
# 187
# [[1.6256847e-03 8.3709529e-05 2.5355530e-01 8.0507249e-03 7.0330155e-01
#   3.0165045e-02 3.2179763e-03]]
# 0.70330155
# None
# 188
# [[1.1824553e-01 5.1523896e-04 9.7292364e-03 2.1550553e-01 2.1431725e-01
#   4.4152129e-01 1.6582529e-04]]
# 0.4415213
# None
# 189
# [[5.7214993e-01 3.8335109e-03 2.7007177e-01 1.1263501e-06 3.3106708e-03
#   1.5060507e-01 2.7899041e-05]]
# 0.57214993
# None
# 190
# Image doesn't exist
# 191
# Image doesn't exist
# 192
# Image doesn't exist
# 193
# Image doesn't exist
# 194
# [[0.02120457 0.00236448 0.2503264  0.01333818 0.5740206  0.13016398
#   0.00858169]]
# 0.5740206
# None
# 195
# Image doesn't exist
# 196
# Image doesn't exist
# 197
# [[8.9031711e-02 2.8211381e-02 2.3962307e-01 2.4779523e-05 4.5510050e-02
#   5.0618201e-01 9.1416970e-02]]
# 0.506182
# None
# 198
# [[5.5381870e-01 6.2268516e-03 1.7157207e-01 1.7936282e-04 2.8256673e-02
#   2.3993923e-01 7.1305085e-06]]
# 0.5538187
# None
# 199
# Image doesn't exist
# 200
# Image doesn't exist
# 201
# [[7.7968049e-03 2.0536043e-05 4.5739010e-01 1.3821959e-03 1.9364281e-02
#   5.1404518e-01 9.2312013e-07]]
# 0.5140452
# None
# 202
# Image doesn't exist
# 203
# Image doesn't exist
# 204
# [[3.2543600e-01 1.7366083e-03 4.7209245e-01 6.6967827e-05 1.6625236e-01
#   9.2764525e-03 2.5139134e-02]]
# 0.47209245
# None
# 205
# [[4.5084074e-01 2.7749266e-03 2.0135508e-01 2.4702874e-04 4.7180922e-05
#   3.4429660e-01 4.3850334e-04]]
# 0.45084074
# None
# 206
# Image doesn't exist
# 207
# Image doesn't exist
# 208
# Image doesn't exist
# 209
# [[0.7042633  0.02730882 0.08367137 0.00083803 0.13826483 0.04487875
#   0.00077484]]
# 0.7042633
# None
# 210
# Image doesn't exist
# 211
# [[4.9779928e-01 3.4357565e-03 8.9846566e-02 1.7024043e-04 1.0196270e-01
#   3.0234075e-01 4.4447519e-03]]
# 0.49779928
# None
# 212
# Image doesn't exist
# 213
# Image doesn't exist
# 214
# Image doesn't exist
# 215
# [[4.8442143e-03 7.9349056e-04 8.8483226e-01 4.2862448e-04 4.0683132e-03
#   1.3192797e-02 9.1840245e-02]]
# 0.88483226
# None
# 216
# Image doesn't exist
# 217
# Image doesn't exist
# 218
# Image doesn't exist
# 219
# Image doesn't exist
# 220
# Image doesn't exist
# 221
# Image doesn't exist
# 222
# Image doesn't exist
# 223
# Image doesn't exist
# 224
# Image doesn't exist
# 225
# Image doesn't exist
# 226
# Image doesn't exist
# 227
# Image doesn't exist
# 228
# Image doesn't exist
# 229
# Image doesn't exist
# 230
# [[7.1243834e-01 1.8289645e-04 6.9595397e-02 4.3002251e-03 3.7076600e-02
#   1.6249685e-01 1.3909686e-02]]
# 0.71243834
# None
# 231
# Image doesn't exist
# 232
# Image doesn't exist
# 233
# Image doesn't exist
# 234
# Image doesn't exist
# 235
# Image doesn't exist
# 236
# [[1.1568689e-05 4.3406960e-08 9.8161465e-01 4.0520110e-05 9.4148672e-05
#   1.8224005e-02 1.5111514e-05]]
# 0.98161465
# None
# 237
# [[0.00924475 0.00997706 0.6595383  0.00133435 0.0253129  0.05498606
#   0.23960662]]
# 0.6595383
# None
# 238
# [[1.5854964e-03 6.2075723e-04 4.0041378e-01 4.8971837e-05 6.9426181e-04
#   5.9592557e-01 7.1110943e-04]]
# 0.59592557
# None
# 239
# Image doesn't exist
# 240
# [[3.3671115e-02 1.5319550e-03 2.0192666e-01 2.4698436e-04 5.2890950e-01
#   2.3219740e-01 1.5163774e-03]]
# 0.5289095
# None
# 241
# Image doesn't exist
# 242
# Image doesn't exist
# 243
# [[1.9251965e-01 6.0642138e-02 5.0220644e-01 1.7426917e-04 1.1876373e-01
#   1.1125440e-01 1.4439357e-02]]
# 0.50220644
# None
# 244
# [[0.606087   0.01590662 0.3081576  0.0033633  0.01159759 0.00785048
#   0.04703745]]
# 0.606087
# None
# 245
# Image doesn't exist
# 246
# [[2.9178622e-01 2.3037102e-02 1.5012178e-01 2.8435836e-02 5.3337347e-02
#   4.5318988e-01 9.1909722e-05]]
# 0.45318988
# None
# 247
# Image doesn't exist
# 248
# Image doesn't exist
# 249
# Image doesn't exist
# 250
# Image doesn't exist
# 251
# Image doesn't exist
# 252
# Image doesn't exist
# 253
# Image doesn't exist
# 254
# Image doesn't exist
# 255
# Image doesn't exist
# 256
# Image doesn't exist
# 257
# Image doesn't exist
# 258
# Image doesn't exist
# 259
# Image doesn't exist
# 260
# Image doesn't exist
# 261
# [[1.7626360e-01 3.3041134e-03 7.7957004e-01 5.4026511e-04 8.7676372e-04
#   1.9543683e-02 1.9901417e-02]]
# 0.77957004
# None
# 262
# Image doesn't exist
# 263
# Image doesn't exist
# 264
# Image doesn't exist
# 265
# Image doesn't exist
# 266
# [[8.4630445e-02 2.7546850e-05 4.5784122e-01 3.7212253e-03 2.8447157e-01
#   1.6735663e-01 1.9513507e-03]]
# 0.45784122
# None
# 267
# Image doesn't exist
# 268
# [[1.6741150e-03 7.0960914e-07 8.5678440e-01 2.1465873e-06 1.8930936e-03
#   9.0025846e-05 1.3955556e-01]]
# 0.8567844
# None
# 269
# [[1.1054865e-02 7.7438483e-04 7.4782930e-02 2.8293545e-03 2.8649025e-02
#   8.5940135e-01 2.2508044e-02]]
# 0.85940135
# None
# 270
# [[2.6458576e-02 8.3098043e-05 8.5538752e-02 3.0427656e-05 1.9856544e-01
#   6.5503174e-01 3.4291990e-02]]
# 0.65503174
# None
# 271
# Image doesn't exist
# 272
# [[3.2876438e-01 5.4830732e-03 4.5977518e-01 2.8203923e-04 6.8782654e-04
#   2.0464379e-01 3.6368435e-04]]
# 0.45977518
# None
# 273
# Image doesn't exist
# 274
# Image doesn't exist
# 275
# [[2.5623245e-02 4.5793211e-05 2.9634410e-01 8.3077885e-04 1.6749848e-01
#   2.1175161e-01 2.9790601e-01]]
# 0.297906
# None
# 276
# [[2.7890282e-02 6.1508996e-05 1.8682496e-01 1.8589330e-04 6.9156432e-01
#   9.2301607e-02 1.1713835e-03]]
# 0.6915643
# None
# 277
# Image doesn't exist
# 278
# Image doesn't exist
# 279
# Image doesn't exist
# 280
# [[2.2643530e-01 6.1465689e-04 7.2178853e-01 4.1800689e-05 2.5772389e-02
#   2.1799473e-02 3.5478426e-03]]
# 0.7217885
# None
# 281
# Image doesn't exist
# 282
# Image doesn't exist
# 283
# Image doesn't exist
# 284
# [[5.4251705e-04 2.8703746e-05 9.7209352e-01 2.9032186e-03 1.4297728e-03
#   4.9493122e-03 1.8052990e-02]]
# 0.9720935
# None
# 285
# Image doesn't exist
# 286
# Image doesn't exist
# 287
# [[0.42364594 0.00141255 0.04099625 0.02022684 0.18561925 0.30981886
#   0.01828035]]
# 0.42364594
# None
# 288
# Image doesn't exist
# 289
# Image doesn't exist
# 290
# Image doesn't exist
# 291
# Image doesn't exist
# 292
# Image doesn't exist
# 293
# Image doesn't exist
# 294
# Image doesn't exist
# 295
# Image doesn't exist
# 296
# [[5.8427459e-04 6.9049878e-05 7.4297416e-01 2.9442293e-05 1.4499062e-03
#   2.5472894e-01 1.6425679e-04]]
# 0.74297416
# None
# 297
# Image doesn't exist
# 298
# Image doesn't exist
# 299
# Image doesn't exist
# 300
# Image doesn't exist
# 301
# [[0.04344505 0.00301873 0.12150274 0.00098444 0.01338002 0.531927
#   0.285742  ]]
# 0.531927
# None
# 302
# [[0.00708221 0.00932793 0.36710256 0.04233107 0.02144583 0.5520096
#   0.00070085]]
# 0.5520096
# None
# 303
# Image doesn't exist
# 304
# Image doesn't exist
# 305
# [[0.03930439 0.22193204 0.07706793 0.0075947  0.6183897  0.03362086
#   0.00209036]]
# 0.6183897
# None
# 306
# [[5.3207604e-03 3.3538054e-05 4.9418393e-01 1.4003542e-02 5.8347854e-04
#   2.5385927e-02 4.6048886e-01]]
# 0.49418393
# None
# 307
# Image doesn't exist
# 308
# [[6.9443882e-02 2.1446585e-06 2.9777145e-01 2.4076474e-03 3.8599801e-08
#   1.2308909e-05 6.3036257e-01]]
# 0.6303626
# None
# 309
# [[2.8864220e-02 3.3812407e-02 8.2644619e-02 6.4758054e-04 6.0331774e-01
#   2.5029603e-01 4.1743173e-04]]
# 0.60331774
# None
# 310
# [[6.7877085e-03 3.6766739e-06 2.3049912e-01 8.1918034e-04 4.0353931e-02
#   7.2102076e-01 5.1559380e-04]]
# 0.72102076
# None
# 311
# Image doesn't exist
# 312
# [[4.6686527e-01 7.0535264e-04 2.7538636e-01 1.7810821e-06 7.5760685e-02
#   1.8123238e-01 4.8141690e-05]]
# 0.46686527
# None
# 313
# Image doesn't exist
# 314
# Image doesn't exist
# 315
# [[3.7194859e-02 4.5515604e-05 4.4755718e-01 3.3584929e-01 5.2366564e-03
#   1.9138716e-03 1.7220260e-01]]
# 0.44755718
# None
# 316
# Image doesn't exist
# 317
# Image doesn't exist
# 318
# Image doesn't exist
# 319
# Image doesn't exist
# 320
# [[1.55831203e-02 5.15534601e-04 1.26865849e-01 1.92481893e-05
#   7.51804769e-01 1.03129245e-01 2.08230549e-03]]
# 0.75180477
# None
# 321
# Image doesn't exist

# %%
print("angry =", angry)
print("disgust =", disgust)
print("fear =", fear)
print("happy =", happy)
print("sad =", sad)
print("surprise =", surprise)
print("neutral =", neutral)
print("\n")

total = angry + disgust + fear + happy + sad + surprise + neutral
print("Total =", total)

print("fearful precentage % =", (fear/total) *100)
# Out:
# angry = 12
# disgust = 1
# fear = 41
# happy = 4
# sad = 14
# surprise = 23
# neutral = 9
#
#
# Total = 104
# fearful precentage % = 39.42307692307692
